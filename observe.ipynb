# %%
import numpy as np
import scipy as sp
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = np.arange(847);
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %%
print('1,2,3')
# Out:
# 1,2,3
